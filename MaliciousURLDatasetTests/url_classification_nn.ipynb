# %%
import pandas as pd
import sys
sys.path.append("../Handlers")

# %%
from nn_traintest_2 import NeuralNetworkClassifier

# %%
df = pd.read_csv("./malicious_phish_preprocessed.csv")

# %%
X = df.drop(columns=["Unnamed: 0", "url", "type"])
y = df["type"]
del df

# %%
X = pd.get_dummies(X, columns=["tld"], drop_first=True)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
import numpy as np

cnn = NeuralNetworkClassifier("Phishing_urls", multi_class="multi")
cnn.load_data(X, y, reshaping=True, scaler=False)
print(cnn.X.shape)
print(cnn.y.shape)
np.save("X_phishing.npy", cnn.X)
np.save("y_phishing.npy", cnn.y)
# Out:
# (633889, 641, 1)
# (633889,)
