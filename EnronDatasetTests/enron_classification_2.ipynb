# %%
import sys

sys.path.append("../Handlers")

JSON_WRITE_MODE = "overwrite"

# %% [markdown]
# This line here note that the mode is add.

# %% [markdown]
# #### Evaluate different models

# %%
from traintest import ClassificationModel2, add_to_json_array

metric_results = []

# %% [markdown]
# ## Stemming + CountVectorizer

# %%
import joblib

# enron_stemmed_countvec = joblib.load("./preprocess/enron_stemmed_countvec.pkl")

# %%
# enron_stemmed_countvec_X, enron_y = enron_stemmed_countvec["features"], enron_stemmed_countvec["labels"]
# print(enron_stemmed_countvec_X.shape)

# del enron_stemmed_countvec

# %%
# clsml2 = ClassificationModel2(enron_stemmed_countvec_X, enron_y, "enron_stemmed_countvec")
# clsml2.split()

# m_r = clsml2.train_and_evaluate_models(
#     valid_size=0.1,
#     max_workers=4,
#     nomlp=True,
#     threading=True,
#     save_plot=True
# )

# metric_results.extend(m_r)

# del enron_stemmed_countvec_X, enron_y, m_r

# %%
# del clsml2

# %%
# metric_results

# %% [markdown]
# ## Stemming + TF-IDF Vectorizer

# %%
# enron_stemmed_tfidf = joblib.load("./preprocess/enron_stemmed_tfidf.pkl")

# %%
# enron_stemmed_tfidf_X, enron_y = enron_stemmed_tfidf["features"], enron_stemmed_tfidf["labels"]

# del enron_stemmed_tfidf

# %%
# clsml2 = ClassificationModel2(enron_stemmed_tfidf_X, enron_y, "enron_stemmed_tfidf")
# clsml2.split()

# m_r = clsml2.train_and_evaluate_models(
#     valid_size=0.1,
#     max_workers=4,
#     nomlp=True,
#     threading=False,
#     save_plot=True,
#     skipping_train_val_accuracy=True
# )

# metric_results.extend(m_r)

# del enron_stemmed_tfidf_X, enron_y, m_r

# %%
# del clsml2

# %%
# metric_results

# %% [markdown]
# ## Lemmatizing + CountVectorizer

# %%
# enron_lemmatized_countvec = joblib.load("./preprocess/enron_lemmatized_countvec.pkl")

# %%
# enron_lemmatized_countvec_X, enron_y = enron_lemmatized_countvec["features"], enron_lemmatized_countvec["labels"]

# del enron_lemmatized_countvec

# %%
# clsml2 = ClassificationModel2(enron_lemmatized_countvec_X, enron_y, "enron_lemmatized_countvec")
# clsml2.split()

# m_r = clsml2.train_and_evaluate_models(
#     valid_size=0.1,
#     max_workers=4,
#     nomlp=True,
#     threading=True,
#     save_plot=True
# )

# metric_results.extend(m_r)

# del enron_lemmatized_countvec_X, enron_y, m_r

# %%
# del clsml2

# %%
# metric_results

# %% [markdown]
# ## Lemmatizing + TF-IDF Vectorizer

# %%
enron_lemmatized_tfidf = joblib.load("./preprocess/enron_lemmatized_tfidf.pkl")

# %%
enron_lemmatized_tfidf_X, enron_y = enron_lemmatized_tfidf["features"], enron_lemmatized_tfidf["labels"]

# %%
clsml2 = ClassificationModel2(enron_lemmatized_tfidf_X, enron_y, "enron_lemmatized_tfidf")
clsml2.split(test_size=0.2, valid_size=0)

m_r = clsml2.train_and_evaluate_models(
    valid_size=0,
    max_workers=4,
    nomlp=True,
    threading=False,
    save_plot=True
)

metric_results.extend(m_r)

del enron_lemmatized_tfidf_X, enron_y, m_r
# Out:
# Begin LinearSVC
# Skipping training and validation accuracy calculation.
# LinearSVC classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'LinearSVC', 'metrics': {'accuracy': 0.9899154678926294, 'weighted_precision': 0.9899685402368268, 'wighted_recall': 0.9899154678926294, 'weighted_f1': 0.9899137494614516, 'macro_precision': 0.9901004839814287, 'macro_recall': 0.9897665305455532, 'macro_f1': 0.9899052050397623, 'roc_auc': 0.9897665305455532}, 'confusion_matrix': array([[3230,   52],
#        [  16, 3445]], dtype=int64), 'epochs': 10}
#
#
# Begin MultinomialNB
# Skipping training and validation accuracy calculation.
# MultinomialNB classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'MultinomialNB', 'metrics': {'accuracy': 0.9876909387512977, 'weighted_precision': 0.9876991462884057, 'wighted_recall': 0.9876909387512977, 'weighted_f1': 0.9876901503066002, 'macro_precision': 0.9877481179264838, 'macro_recall': 0.9876231644294102, 'macro_f1': 0.9876807415332103, 'roc_auc': 0.9876231644294102}, 'confusion_matrix': array([[3233,   49],
#        [  34, 3427]], dtype=int64), 'epochs': 10}
#
#
# Begin BernoulliNB
# Skipping training and validation accuracy calculation.
# BernoulliNB classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'BernoulliNB', 'metrics': {'accuracy': 0.9836867862969005, 'weighted_precision': 0.983853202950439, 'wighted_recall': 0.9836867862969005, 'weighted_f1': 0.9836811992304708, 'macro_precision': 0.9840859262393716, 'macro_recall': 0.9834231475617312, 'macro_f1': 0.98366557290405, 'roc_auc': 0.9834231475617312}, 'confusion_matrix': array([[3195,   87],
#        [  23, 3438]], dtype=int64), 'epochs': 10}
#
#
# Begin RandomForestClassifier
# Skipping training and validation accuracy calculation.
# RandomForestClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'RandomForestClassifier', 'metrics': {'accuracy': 0.9860596173809877, 'weighted_precision': 0.9860901053454607, 'wighted_recall': 0.9860596173809877, 'weighted_f1': 0.9860578386665811, 'macro_precision': 0.9861875579461872, 'macro_recall': 0.9859394777815869, 'macro_f1': 0.9860464675994822, 'roc_auc': 0.9859394777815867}, 'confusion_matrix': array([[3221,   61],
#        [  33, 3428]], dtype=int64), 'epochs': 10}
#
#
# Begin DecisionTreeClassifier
# Skipping training and validation accuracy calculation.
# DecisionTreeClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'DecisionTreeClassifier', 'metrics': {'accuracy': 0.9529882841465224, 'weighted_precision': 0.9530292022378594, 'wighted_recall': 0.9529882841465224, 'weighted_f1': 0.9529800123255083, 'macro_precision': 0.9531281797831206, 'macro_recall': 0.9528093665270945, 'macro_f1': 0.9529399945968191, 'roc_auc': 0.9528093665270945}, 'confusion_matrix': array([[3105,  177],
#        [ 140, 3321]], dtype=int64), 'epochs': 10}
#
#
# Begin AdaBoostClassifier
# Skipping training and validation accuracy calculation.
# AdaBoostClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'AdaBoostClassifier', 'metrics': {'accuracy': 0.947946018092837, 'weighted_precision': 0.9486326068189911, 'wighted_recall': 0.947946018092837, 'weighted_f1': 0.9478963462669231, 'macro_precision': 0.9490811447094349, 'macro_recall': 0.9473695840532469, 'macro_f1': 0.9478314465819698, 'roc_auc': 0.9473695840532468}, 'confusion_matrix': array([[3038,  244],
#        [ 107, 3354]], dtype=int64), 'epochs': 10}
#
#
# Begin LogisticRegression
# Skipping training and validation accuracy calculation.
# LogisticRegression classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'LogisticRegression', 'metrics': {'accuracy': 0.9841316921251668, 'weighted_precision': 0.9843882726455233, 'wighted_recall': 0.9841316921251668, 'weighted_f1': 0.9841245683967006, 'macro_precision': 0.9846789556401043, 'macro_recall': 0.9838092730329654, 'macro_f1': 0.9841084272904289, 'roc_auc': 0.9838092730329654}, 'confusion_matrix': array([[3189,   93],
#        [  14, 3447]], dtype=int64), 'epochs': 10}
#
#
# Begin SGDClassifier
# Skipping training and validation accuracy calculation.
# SGDClassifier classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'SGDClassifier', 'metrics': {'accuracy': 0.9869494290375204, 'weighted_precision': 0.9871080509054363, 'wighted_recall': 0.9869494290375204, 'weighted_f1': 0.9869451347902458, 'macro_precision': 0.9873370292470245, 'macro_recall': 0.9866959702973905, 'macro_f1': 0.9869327368827919, 'roc_auc': 0.9866959702973906}, 'confusion_matrix': array([[3207,   75],
#        [  13, 3448]], dtype=int64), 'epochs': 10}
#
#
# Begin Perceptron
# Skipping training and validation accuracy calculation.
# Perceptron classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'Perceptron', 'metrics': {'accuracy': 0.9839833901824114, 'weighted_precision': 0.9839922810781276, 'wighted_recall': 0.9839833901824114, 'weighted_f1': 0.9839822902089086, 'macro_precision': 0.9840420145260403, 'macro_recall': 0.9839090617291906, 'macro_f1': 0.9839699842553462, 'roc_auc': 0.9839090617291906}, 'confusion_matrix': array([[3220,   62],
#        [  46, 3415]], dtype=int64), 'epochs': 10}
#
#
# Begin PassiveAggressiveClassifier
# Skipping training and validation accuracy calculation.
# PassiveAggressiveClassifier classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'PassiveAggressiveClassifier', 'metrics': {'accuracy': 0.9890256562360967, 'weighted_precision': 0.9890380524485267, 'wighted_recall': 0.9890256562360967, 'weighted_f1': 0.9890247996287004, 'macro_precision': 0.9890996891714432, 'macro_recall': 0.988947004323091, 'macro_f1': 0.9890162811440384, 'roc_auc': 0.9889470043230911}, 'confusion_matrix': array([[3236,   46],
#        [  28, 3433]], dtype=int64), 'epochs': 10}
#
#
# Begin ExtraTreesClassifier
# Skipping training and validation accuracy calculation.
# ExtraTreesClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'ExtraTreesClassifier', 'metrics': {'accuracy': 0.9873943348657868, 'weighted_precision': 0.9874002964662304, 'wighted_recall': 0.9873943348657868, 'weighted_f1': 0.9873936423075764, 'macro_precision': 0.9874413397923623, 'macro_recall': 0.9873342305952583, 'macro_f1': 0.9873841063137578, 'roc_auc': 0.9873342305952583}, 'confusion_matrix': array([[3233,   49],
#        [  36, 3425]], dtype=int64), 'epochs': 10}
#
#
# Begin XGBClassifier
# Skipping training and validation accuracy calculation.
# XGBClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'XGBClassifier', 'metrics': {'accuracy': 0.9756784813881062, 'weighted_precision': 0.9762024063977942, 'wighted_recall': 0.9756784813881062, 'weighted_f1': 0.9756605803748305, 'macro_precision': 0.9766137334887335, 'macro_recall': 0.9752122149463482, 'macro_f1': 0.9756324726434593, 'roc_auc': 0.9752122149463482}, 'confusion_matrix': array([[3143,  139],
#        [  25, 3436]], dtype=int64), 'epochs': 10}
#
#
# Begin KNeighborsClassifier
# Skipping training and validation accuracy calculation.
# KNeighborsClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'KNeighborsClassifier', 'metrics': {'accuracy': 0.6944979979237728, 'weighted_precision': 0.8077403614422367, 'wighted_recall': 0.6944979979237728, 'weighted_f1': 0.6598122398985706, 'macro_precision': 0.8126699293094073, 'macro_recall': 0.6861827297855921, 'macro_f1': 0.656792419525754, 'roc_auc': 0.686182729785592}, 'confusion_matrix': array([[1224, 2058],
#        [   2, 3459]], dtype=int64), 'epochs': 10}
#
#
# Begin BaggingClassifier
# Skipping training and validation accuracy calculation.
# BaggingClassifier classification report
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'BaggingClassifier', 'metrics': {'accuracy': 0.9650007415097138, 'weighted_precision': 0.9650177099625914, 'wighted_recall': 0.9650007415097138, 'weighted_f1': 0.9649969878612679, 'macro_precision': 0.9650809881514479, 'macro_recall': 0.9648815098368677, 'macro_f1': 0.9649689918999428, 'roc_auc': 0.9648815098368677}, 'confusion_matrix': array([[3152,  130],
#        [ 106, 3355]], dtype=int64), 'epochs': 10}
#
#
# Begin VotingClassifier
# Skipping training and validation accuracy calculation.
# VotingClassifier classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'enron_lemmatized_tfidf', 'model': 'VotingClassifier', 'metrics': {'accuracy': 0.9900637698353848, 'weighted_precision': 0.9901331387736354, 'wighted_recall': 0.9900637698353848, 'weighted_f1': 0.9900617965749556, 'macro_precision': 0.9902845660900608, 'macro_recall': 0.9898952390359645, 'macro_f1': 0.9900531816086909, 'roc_auc': 0.9898952390359647}, 'confusion_matrix': array([[3228,   54],
#        [  13, 3448]], dtype=int64), 'epochs': 10}

# %%
del clsml2

# %%
print(metric_results)

def convert(dic):
    dic["confusion_matrix"] = dic["confusion_matrix"].tolist()
    return dic

metric_results = list(map(convert, metric_results))

add_to_json_array("./merged_enron_classification_report.json", metric_results, mode=JSON_WRITE_MODE)
# Out:
# [{'dataset': 'enron_lemmatized_tfidf', 'model': 'LinearSVC', 'metrics': {'accuracy': 0.9899154678926294, 'weighted_precision': 0.9899685402368268, 'wighted_recall': 0.9899154678926294, 'weighted_f1': 0.9899137494614516, 'macro_precision': 0.9901004839814287, 'macro_recall': 0.9897665305455532, 'macro_f1': 0.9899052050397623, 'roc_auc': 0.9897665305455532}, 'confusion_matrix': array([[3230,   52],
#        [  16, 3445]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'MultinomialNB', 'metrics': {'accuracy': 0.9876909387512977, 'weighted_precision': 0.9876991462884057, 'wighted_recall': 0.9876909387512977, 'weighted_f1': 0.9876901503066002, 'macro_precision': 0.9877481179264838, 'macro_recall': 0.9876231644294102, 'macro_f1': 0.9876807415332103, 'roc_auc': 0.9876231644294102}, 'confusion_matrix': array([[3233,   49],
#        [  34, 3427]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'BernoulliNB', 'metrics': {'accuracy': 0.9836867862969005, 'weighted_precision': 0.983853202950439, 'wighted_recall': 0.9836867862969005, 'weighted_f1': 0.9836811992304708, 'macro_precision': 0.9840859262393716, 'macro_recall': 0.9834231475617312, 'macro_f1': 0.98366557290405, 'roc_auc': 0.9834231475617312}, 'confusion_matrix': array([[3195,   87],
#        [  23, 3438]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'RandomForestClassifier', 'metrics': {'accuracy': 0.9860596173809877, 'weighted_precision': 0.9860901053454607, 'wighted_recall': 0.9860596173809877, 'weighted_f1': 0.9860578386665811, 'macro_precision': 0.9861875579461872, 'macro_recall': 0.9859394777815869, 'macro_f1': 0.9860464675994822, 'roc_auc': 0.9859394777815867}, 'confusion_matrix': array([[3221,   61],
#        [  33, 3428]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'DecisionTreeClassifier', 'metrics': {'accuracy': 0.9529882841465224, 'weighted_precision': 0.9530292022378594, 'wighted_recall': 0.9529882841465224, 'weighted_f1': 0.9529800123255083, 'macro_precision': 0.9531281797831206, 'macro_recall': 0.9528093665270945, 'macro_f1': 0.9529399945968191, 'roc_auc': 0.9528093665270945}, 'confusion_matrix': array([[3105,  177],
#        [ 140, 3321]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'AdaBoostClassifier', 'metrics': {'accuracy': 0.947946018092837, 'weighted_precision': 0.9486326068189911, 'wighted_recall': 0.947946018092837, 'weighted_f1': 0.9478963462669231, 'macro_precision': 0.9490811447094349, 'macro_recall': 0.9473695840532469, 'macro_f1': 0.9478314465819698, 'roc_auc': 0.9473695840532468}, 'confusion_matrix': array([[3038,  244],
#        [ 107, 3354]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'LogisticRegression', 'metrics': {'accuracy': 0.9841316921251668, 'weighted_precision': 0.9843882726455233, 'wighted_recall': 0.9841316921251668, 'weighted_f1': 0.9841245683967006, 'macro_precision': 0.9846789556401043, 'macro_recall': 0.9838092730329654, 'macro_f1': 0.9841084272904289, 'roc_auc': 0.9838092730329654}, 'confusion_matrix': array([[3189,   93],
#        [  14, 3447]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'SGDClassifier', 'metrics': {'accuracy': 0.9869494290375204, 'weighted_precision': 0.9871080509054363, 'wighted_recall': 0.9869494290375204, 'weighted_f1': 0.9869451347902458, 'macro_precision': 0.9873370292470245, 'macro_recall': 0.9866959702973905, 'macro_f1': 0.9869327368827919, 'roc_auc': 0.9866959702973906}, 'confusion_matrix': array([[3207,   75],
#        [  13, 3448]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'Perceptron', 'metrics': {'accuracy': 0.9839833901824114, 'weighted_precision': 0.9839922810781276, 'wighted_recall': 0.9839833901824114, 'weighted_f1': 0.9839822902089086, 'macro_precision': 0.9840420145260403, 'macro_recall': 0.9839090617291906, 'macro_f1': 0.9839699842553462, 'roc_auc': 0.9839090617291906}, 'confusion_matrix': array([[3220,   62],
#        [  46, 3415]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'PassiveAggressiveClassifier', 'metrics': {'accuracy': 0.9890256562360967, 'weighted_precision': 0.9890380524485267, 'wighted_recall': 0.9890256562360967, 'weighted_f1': 0.9890247996287004, 'macro_precision': 0.9890996891714432, 'macro_recall': 0.988947004323091, 'macro_f1': 0.9890162811440384, 'roc_auc': 0.9889470043230911}, 'confusion_matrix': array([[3236,   46],
#        [  28, 3433]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'ExtraTreesClassifier', 'metrics': {'accuracy': 0.9873943348657868, 'weighted_precision': 0.9874002964662304, 'wighted_recall': 0.9873943348657868, 'weighted_f1': 0.9873936423075764, 'macro_precision': 0.9874413397923623, 'macro_recall': 0.9873342305952583, 'macro_f1': 0.9873841063137578, 'roc_auc': 0.9873342305952583}, 'confusion_matrix': array([[3233,   49],
#        [  36, 3425]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'XGBClassifier', 'metrics': {'accuracy': 0.9756784813881062, 'weighted_precision': 0.9762024063977942, 'wighted_recall': 0.9756784813881062, 'weighted_f1': 0.9756605803748305, 'macro_precision': 0.9766137334887335, 'macro_recall': 0.9752122149463482, 'macro_f1': 0.9756324726434593, 'roc_auc': 0.9752122149463482}, 'confusion_matrix': array([[3143,  139],
#        [  25, 3436]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'KNeighborsClassifier', 'metrics': {'accuracy': 0.6944979979237728, 'weighted_precision': 0.8077403614422367, 'wighted_recall': 0.6944979979237728, 'weighted_f1': 0.6598122398985706, 'macro_precision': 0.8126699293094073, 'macro_recall': 0.6861827297855921, 'macro_f1': 0.656792419525754, 'roc_auc': 0.686182729785592}, 'confusion_matrix': array([[1224, 2058],
#        [   2, 3459]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'BaggingClassifier', 'metrics': {'accuracy': 0.9650007415097138, 'weighted_precision': 0.9650177099625914, 'wighted_recall': 0.9650007415097138, 'weighted_f1': 0.9649969878612679, 'macro_precision': 0.9650809881514479, 'macro_recall': 0.9648815098368677, 'macro_f1': 0.9649689918999428, 'roc_auc': 0.9648815098368677}, 'confusion_matrix': array([[3152,  130],
#        [ 106, 3355]], dtype=int64), 'epochs': 10}, {'dataset': 'enron_lemmatized_tfidf', 'model': 'VotingClassifier', 'metrics': {'accuracy': 0.9900637698353848, 'weighted_precision': 0.9901331387736354, 'wighted_recall': 0.9900637698353848, 'weighted_f1': 0.9900617965749556, 'macro_precision': 0.9902845660900608, 'macro_recall': 0.9898952390359645, 'macro_f1': 0.9900531816086909, 'roc_auc': 0.9898952390359647}, 'confusion_matrix': array([[3228,   54],
#        [  13, 3448]], dtype=int64), 'epochs': 10}]
