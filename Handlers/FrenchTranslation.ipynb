# %%
from transformers import MarianMTModel, MarianTokenizer, M2M100ForConditionalGeneration

model_name = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

def translate(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

    # Perform translation
    translated = model.generate(**inputs)

    # Decode the translated tokens to text
    translated_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
    return translated_text

def translate_and_merge(texts: list) -> str:
    """
    Translate a list of texts and merge them into a single string.
    
    Args:
        texts (list): List of strings to translate.
        
    Returns:
        str: Merged translated text.
    """
    # Translate each text in the list
    translated_texts = [translate(text)[0] for text in texts]
    
    # Merge the translated texts into a single string
    merged_text = " ".join(translated_texts)
    
    return merged_text
# Out:
# d:\Anaconda2\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# d:\Anaconda2\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 model_name = "Helsinki-NLP/opus-mt-en-fr"
#       4 tokenizer = MarianTokenizer.from_pretrained(model_name)
# ----> 5 model = MarianMTModel.from_pretrained(model_name)
#       7 def translate(text):
#       8     # Tokenize the input text
#       9     inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
#
# File d:\Anaconda2\Lib\site-packages\transformers\modeling_utils.py:3301, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3298 if commit_hash is None:
#    3299     if not isinstance(config, PretrainedConfig):
#    3300         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# -> 3301         resolved_config_file = cached_file(
#    3302             pretrained_model_name_or_path,
#    3303             CONFIG_NAME,
#    3304             cache_dir=cache_dir,
#    3305             force_download=force_download,
#    3306             resume_download=resume_download,
#    3307             proxies=proxies,
#    3308             local_files_only=local_files_only,
#    3309             token=token,
#    3310             revision=revision,
#    3311             subfolder=subfolder,
#    3312             _raise_exceptions_for_gated_repo=False,
#    3313             _raise_exceptions_for_missing_entries=False,
#    3314             _raise_exceptions_for_connection_errors=False,
#    3315         )
#    3316         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#    3317     else:
#
# File d:\Anaconda2\Lib\site-packages\transformers\utils\hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File d:\Anaconda2\Lib\site-packages\huggingface_hub\utils\_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\huggingface_hub\file_download.py:1194, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1191 if repo_type not in constants.REPO_TYPES:
#    1192     raise ValueError(f"Invalid repo type: {repo_type}. Accepted repo types are: {str(constants.REPO_TYPES)}")
# -> 1194 headers = build_hf_headers(
#    1195     token=token,
#    1196     library_name=library_name,
#    1197     library_version=library_version,
#    1198     user_agent=user_agent,
#    1199     headers=headers,
#    1200 )
#    1202 if local_dir is not None:
#    1203     if local_dir_use_symlinks != "auto":
#
# File d:\Anaconda2\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\huggingface_hub\utils\_headers.py:125, in build_hf_headers(token, is_write_action, library_name, library_version, user_agent, headers)
#     123 # Get auth token to send
#     124 token_to_send = get_token_to_send(token)
# --> 125 _validate_token_to_send(token_to_send, is_write_action=is_write_action)
#     127 # Combine headers
#     128 hf_headers = {
#     129     "user-agent": _http_user_agent(
#     130         library_name=library_name,
#    (...)
#     133     )
#     134 }
#
# File d:\Anaconda2\Lib\site-packages\huggingface_hub\utils\_headers.py:174, in _validate_token_to_send(token, is_write_action)
#     170     # Otherwise: we use the cached token as the user has not explicitly forbidden it
#     171     return cached_token
# --> 174 def _validate_token_to_send(token: Optional[str], is_write_action: bool) -> None:
#     175     if is_write_action:
#     176         if token is None:
#
# KeyboardInterrupt:

# %%
import nltk.data

tokenizer_nltk = nltk.data.load('tokenizers/punkt/english.pickle')
text = "Would you like to go out for dinner? I would love to go out for dinner!"
text_split = tokenizer_nltk.tokenize(text)
text_split
# Out:
# ['Would you like to go out for dinner?', 'I would love to go out for dinner!']

# %%
list(map(lambda x: translate(x), text_split))
# Out:
# [['Voulez-vous sortir dîner ?'], ["J'adorerais sortir dîner !"]]

# %%
import pandas as pd

df = pd.read_csv("./Datasets/email_text.csv")
df["French Text"] = df["text"].apply(lambda x: translate_and_merge(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 df = pd.read_csv("./Datasets/email_text.csv")
# ----> 4 df["French Text"] = df["text"].apply(lambda x: translate_and_merge(x))
#
# File d:\Anaconda2\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File d:\Anaconda2\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File d:\Anaconda2\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File d:\Anaconda2\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File d:\Anaconda2\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[4], line 4, in <lambda>(x)
#       1 import pandas as pd
#       3 df = pd.read_csv("./Datasets/email_text.csv")
# ----> 4 df["French Text"] = df["text"].apply(lambda x: translate_and_merge(x))
#
# Cell In[1], line 29, in translate_and_merge(texts)
#      19 """
#      20 Translate a list of texts and merge them into a single string.
#      21
#    (...)
#      26     str: Merged translated text.
#      27 """
#      28 # Translate each text in the list
# ---> 29 translated_texts = [translate(text)[0] for text in texts]
#      31 # Merge the translated texts into a single string
#      32 merged_text = " ".join(translated_texts)
#
# Cell In[1], line 12, in translate(text)
#       9 inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
#      11 # Perform translation
# ---> 12 translated = model.generate(**inputs)
#      14 # Decode the translated tokens to text
#      15 translated_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
#
# File d:\Anaconda2\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\transformers\generation\utils.py:2079, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2071     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2072         input_ids=input_ids,
#    2073         expand_size=generation_config.num_beams,
#    2074         is_encoder_decoder=self.config.is_encoder_decoder,
#    2075         **model_kwargs,
#    2076     )
#    2078     # 13. run beam sample
# -> 2079     result = self._beam_search(
#    2080         input_ids,
#    2081         beam_scorer,
#    2082         logits_processor=prepared_logits_processor,
#    2083         stopping_criteria=prepared_stopping_criteria,
#    2084         generation_config=generation_config,
#    2085         synced_gpus=synced_gpus,
#    2086         **model_kwargs,
#    2087     )
#    2089 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2090     # 11. prepare beam search scorer
#    2091     beam_scorer = BeamSearchScorer(
#    2092         batch_size=batch_size,
#    2093         num_beams=generation_config.num_beams,
#    (...)
#    2099         max_length=generation_config.max_length,
#    2100     )
#
# File d:\Anaconda2\Lib\site-packages\transformers\generation\utils.py:3254, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3251     outputs = stack_model_outputs(outputs_per_sub_batch, self.config.get_text_config())
#    3253 else:  # Unchanged original behavior
# -> 3254     outputs = self(**model_inputs, return_dict=True)
#    3256 if synced_gpus and this_peer_finished:
#    3257     cur_len = cur_len + 1
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File d:\Anaconda2\Lib\site-packages\transformers\models\marian\modeling_marian.py:1400, in MarianMTModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1395     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1396         decoder_input_ids = shift_tokens_right(
#    1397             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1398         )
# -> 1400 outputs = self.model(
#    1401     input_ids,
#    1402     attention_mask=attention_mask,
#    1403     decoder_input_ids=decoder_input_ids,
#    1404     encoder_outputs=encoder_outputs,
#    1405     decoder_attention_mask=decoder_attention_mask,
#    1406     head_mask=head_mask,
#    1407     decoder_head_mask=decoder_head_mask,
#    1408     cross_attn_head_mask=cross_attn_head_mask,
#    1409     past_key_values=past_key_values,
#    1410     inputs_embeds=inputs_embeds,
#    1411     decoder_inputs_embeds=decoder_inputs_embeds,
#    1412     use_cache=use_cache,
#    1413     output_attentions=output_attentions,
#    1414     output_hidden_states=output_hidden_states,
#    1415     return_dict=return_dict,
#    1416 )
#    1417 lm_logits = self.lm_head(outputs[0]) + self.final_logits_bias
#    1419 masked_lm_loss = None
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File d:\Anaconda2\Lib\site-packages\transformers\models\marian\modeling_marian.py:1195, in MarianModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1188     encoder_outputs = BaseModelOutput(
#    1189         last_hidden_state=encoder_outputs[0],
#    1190         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1191         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1192     )
#    1194 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1195 decoder_outputs = self.decoder(
#    1196     input_ids=decoder_input_ids,
#    1197     attention_mask=decoder_attention_mask,
#    1198     encoder_hidden_states=encoder_outputs[0],
#    1199     encoder_attention_mask=attention_mask,
#    1200     head_mask=decoder_head_mask,
#    1201     cross_attn_head_mask=cross_attn_head_mask,
#    1202     past_key_values=past_key_values,
#    1203     inputs_embeds=decoder_inputs_embeds,
#    1204     use_cache=use_cache,
#    1205     output_attentions=output_attentions,
#    1206     output_hidden_states=output_hidden_states,
#    1207     return_dict=return_dict,
#    1208 )
#    1210 if not return_dict:
#    1211     return decoder_outputs + encoder_outputs
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File d:\Anaconda2\Lib\site-packages\transformers\models\marian\modeling_marian.py:995, in MarianDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     982     layer_outputs = self._gradient_checkpointing_func(
#     983         decoder_layer.__call__,
#     984         hidden_states,
#    (...)
#     992         use_cache,
#     993     )
#     994 else:
# --> 995     layer_outputs = decoder_layer(
#     996         hidden_states,
#     997         attention_mask=attention_mask,
#     998         encoder_hidden_states=encoder_hidden_states,
#     999         encoder_attention_mask=encoder_attention_mask,
#    1000         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1001         cross_attn_layer_head_mask=(
#    1002             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1003         ),
#    1004         past_key_value=past_key_value,
#    1005         output_attentions=output_attentions,
#    1006         use_cache=use_cache,
#    1007     )
#    1008 hidden_states = layer_outputs[0]
#    1010 if use_cache:
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File d:\Anaconda2\Lib\site-packages\transformers\models\marian\modeling_marian.py:443, in MarianDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     441 hidden_states = self.activation_fn(self.fc1(hidden_states))
#     442 hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
# --> 443 hidden_states = self.fc2(hidden_states)
#     444 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     445 hidden_states = residual + hidden_states
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File d:\Anaconda2\Lib\site-packages\torch\nn\modules\linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
