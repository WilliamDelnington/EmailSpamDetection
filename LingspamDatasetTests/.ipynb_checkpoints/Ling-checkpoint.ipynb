# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
ling = pd.read_csv('ling_preprocessed.csv')
ling
# Out:
#       Unnamed: 0                                  preprocessed_data  label
# 0              0  ['job', 'posting', 'appleiss', 'research', 'ce...      0
# 1              1  ['nan', 'lang', 'classification', 'grimes', 'j...      0
# 2              2  ['query', 'letter', 'frequencies', 'text', 'id...      0
# 3              3  ['risk', 'colleague', 'researching', 'differin...      0
# 4              4  ['request', 'book', 'information', 'earlier', ...      0
# ...          ...                                                ...    ...
# 2854        2854  ['win', 'usd', 'cruise', 'raquel', 'casino', '...      1
# 2855        2855  ['asked', 'join', 'kiddin', 'list', 'owner', '...      1
# 2856        2856  ['anglicization', 'composers', 'names', 'judgi...      0
# 2857        2857  ['comparative', 'method', 'n', 'ary', 'compari...      0
# 2858        2858  ['american', 'english', 'australia', 'hello', ...      0
#
# [2859 rows x 3 columns]

# %%
import sys

sys.path.append("../Handlers")

import preprocessing
from data_visualization import DataVisualization
# Out:
# [nltk_data] Downloading package punkt to E:/nltk...
# [nltk_data]   Package punkt is already up-to-date!

# %%
label_counts = ling["label"].value_counts()

print(label_counts.values)
print(label_counts.index)

dv = DataVisualization()
dv.visualize_class_distribution(label_counts, save=False, type="pie")

# plt.figure(figsize=(8, 6))
# plt.pie(label_counts.values, labels=["ham", "spam"], autopct='%1.1f%%')
# plt.title('Distribution of Ling-spam')
# plt.savefig(os.path.join("./figs", "ling_pie_chart.jpg"))
# plt.show()
# Out:
# [2401  458]
# Int64Index([0, 1], dtype='int64')

# %%
ling_X, ling_y = ling["preprocessed_data"], ling["label"]

import ast

ling_X = ling_X.apply(lambda x: ast.literal_eval(x))

# %%
from traintest import ClassificationModel2, add_to_json_array

metric_results = []

# %% [markdown]
# ## Stemming + CountVectorizer

# %%
# ling_X_stemming = ling_X.apply(preprocessing.stemming)

# %%
# ling_X_stemming_countvec = preprocessing.vectorizing(ling_X_stemming, "countvectorizer")

# %%
# clsml2 = ClassificationModel2(ling_X_stemming_countvec, ling_y, "ling_stemmed_countvec")
# clsml2.split()

# m_r = clsml2.train_and_evaluate_models(
#     valid_size=0.1,
#     max_workers=4,
#     nomlp=True,
#     threading=False,
#     save_plot=True,
#     skipping_train_val_accuracy=True
# )

# metric_results.extend(m_r)

# del ling_X_stemming_countvec, m_r

# %% [markdown]
# ## Stemming + TF-IDF

# %%
# ling_X_stemming_tfidf = preprocessing.vectorizing(ling_X_stemming, "tfidf")

# clsml2 = ClassificationModel2(ling_X_stemming_tfidf, ling_y, "ling_stemmed_tfidf")
# clsml2.split()

# m_r = clsml2.train_and_evaluate_models(
#     valid_size=0.1,
#     max_workers=4,
#     nomlp=True,
#     threading=False,
#     save_plot=True,
#     skipping_train_val_accuracy=True
# )

# metric_results.extend(m_r)

# del m_r
# del ling_X_stemming_tfidf
# del ling_X_stemming

# %% [markdown]
# ## Lemmatizing + CountVectorizer

# %%
ling_X_lemmatizing = ling_X.apply(preprocessing.lemmatizing)

# %%
# ling_X_lemmatizing_countvec = preprocessing.vectorizing(ling_X_lemmatizing, "countvectorizer")

# clsml2 = ClassificationModel2(ling_X_lemmatizing_countvec, ling_y, "spam_assassin_lemmatized_countvec")
# clsml2.split()

# m_r = clsml2.train_and_evaluate_models(
#     valid_size=0.1,
#     max_workers=4,
#     nomlp=True,
#     threading=True,
#     save_plot=True
# )

# metric_results.extend(m_r)

# del m_r

# del ling_X_lemmatizing_countvec

# %% [markdown]
# ## Lemmatizing + TF-IDF

# %%
ling_X_lemmatizing_tfidf = preprocessing.vectorizing(ling_X_lemmatizing, "tfidf")

clsml2 = ClassificationModel2(ling_X_lemmatizing_tfidf, ling_y, "ling_lemmatized_tfidf")
clsml2.split(test_size=0.2, valid_size=0)

m_r = clsml2.train_and_evaluate_models(
    valid_size=0,
    max_workers=4,
    nomlp=True,
    threading=False,
    save_plot=True
)

metric_results.extend(m_r)

del ling_X_lemmatizing_tfidf
del ling_X_lemmatizing
# Out:
# Begin LinearSVC
# Skipping training and validation accuracy calculation.
# LinearSVC classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'LinearSVC', 'metrics': {'accuracy': 0.9982517482517482, 'weighted_precision': 0.9982552658608996, 'wighted_recall': 0.9982517482517482, 'weighted_f1': 0.9982468396265639, 'macro_precision': 0.9989939637826961, 'macro_recall': 0.993421052631579, 'macro_f1': 0.9961852170491454, 'roc_auc': 0.993421052631579}, 'confusion_matrix': array([[496,   0],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9912556795218791, 'std_accuracy': 0.004944806457188462}}
#
#
# Begin MultinomialNB
# Skipping training and validation accuracy calculation.
# MultinomialNB classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'MultinomialNB', 'metrics': {'accuracy': 0.9877622377622378, 'weighted_precision': 0.9879325445925843, 'wighted_recall': 0.9877622377622378, 'weighted_f1': 0.9875097185442012, 'macro_precision': 0.9930417495029822, 'macro_recall': 0.9539473684210527, 'macro_f1': 0.9723585654620137, 'roc_auc': 0.9539473684210527}, 'confusion_matrix': array([[496,   0],
#        [  7,  69]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9727162504745692, 'std_accuracy': 0.008823117011988965}}
#
#
# Begin BernoulliNB
# Skipping training and validation accuracy calculation.
# BernoulliNB classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'BernoulliNB', 'metrics': {'accuracy': 0.9842657342657343, 'weighted_precision': 0.9845461469223845, 'wighted_recall': 0.9842657342657343, 'weighted_f1': 0.9838413334916832, 'macro_precision': 0.9910891089108911, 'macro_recall': 0.9407894736842105, 'macro_f1': 0.964035964035964, 'roc_auc': 0.9407894736842105}, 'confusion_matrix': array([[496,   0],
#        [  9,  67]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9671249066170257, 'std_accuracy': 0.011819431302090783}}
#
#
# Begin RandomForestClassifier
# Skipping training and validation accuracy calculation.
# RandomForestClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'RandomForestClassifier', 'metrics': {'accuracy': 0.9842657342657343, 'weighted_precision': 0.9845461469223845, 'wighted_recall': 0.9842657342657343, 'weighted_f1': 0.9838413334916832, 'macro_precision': 0.9910891089108911, 'macro_recall': 0.9407894736842105, 'macro_f1': 0.964035964035964, 'roc_auc': 0.9407894736842105}, 'confusion_matrix': array([[496,   0],
#        [  9,  67]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9790166925893722, 'std_accuracy': 0.006720090897629651}}
#
#
# Begin DecisionTreeClassifier
# Skipping training and validation accuracy calculation.
# DecisionTreeClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'DecisionTreeClassifier', 'metrics': {'accuracy': 0.9685314685314685, 'weighted_precision': 0.9678831129030333, 'wighted_recall': 0.9685314685314685, 'weighted_f1': 0.9679794496551298, 'macro_precision': 0.9451906659077973, 'macro_recall': 0.9150042444821731, 'macro_f1': 0.9293381283114175, 'roc_auc': 0.9150042444821732}, 'confusion_matrix': array([[490,   6],
#        [ 12,  64]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9548791838634221, 'std_accuracy': 0.004613521579600063}}
#
#
# Begin AdaBoostClassifier
# Skipping training and validation accuracy calculation.
# AdaBoostClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'AdaBoostClassifier', 'metrics': {'accuracy': 0.9877622377622378, 'weighted_precision': 0.9877063781289133, 'wighted_recall': 0.9877622377622378, 'weighted_f1': 0.9877278773859475, 'macro_precision': 0.9759758551307847, 'macro_recall': 0.9706600169779287, 'macro_f1': 0.9732965193440174, 'roc_auc': 0.9706600169779286}, 'confusion_matrix': array([[493,   3],
#        [  4,  72]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9818120583444576, 'std_accuracy': 0.005593653514790113}}
#
#
# Begin LogisticRegression
# Skipping training and validation accuracy calculation.
# LogisticRegression classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'LogisticRegression', 'metrics': {'accuracy': 0.9807692307692307, 'weighted_precision': 0.9811864663935669, 'wighted_recall': 0.9807692307692307, 'weighted_f1': 0.9801245472529493, 'macro_precision': 0.9891518737672584, 'macro_recall': 0.9276315789473684, 'macro_f1': 0.9555093584494743, 'roc_auc': 0.9276315789473684}, 'confusion_matrix': array([[496,   0],
#        [ 11,  65]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9646718430431214, 'std_accuracy': 0.00873915679653664}}
#
#
# Begin SGDClassifier
# Skipping training and validation accuracy calculation.
# SGDClassifier classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'SGDClassifier', 'metrics': {'accuracy': 0.9965034965034965, 'weighted_precision': 0.9965175386862134, 'wighted_recall': 0.9965034965034965, 'weighted_f1': 0.9964837040893378, 'macro_precision': 0.9979919678714859, 'macro_recall': 0.986842105263158, 'macro_f1': 0.9923272971160295, 'roc_auc': 0.986842105263158}, 'confusion_matrix': array([[496,   0],
#        [  2,  74]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9940528823190821, 'std_accuracy': 0.003602254155093064}}
#
#
# Begin Perceptron
# Skipping training and validation accuracy calculation.
# Perceptron classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'Perceptron', 'metrics': {'accuracy': 0.9912587412587412, 'weighted_precision': 0.9915136600375515, 'wighted_recall': 0.9912587412587412, 'weighted_f1': 0.9913300763622038, 'macro_precision': 0.9736693455208361, 'macro_recall': 0.9893887945670627, 'macro_f1': 0.9813431618774259, 'roc_auc': 0.9893887945670629}, 'confusion_matrix': array([[492,   4],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9912562918692516, 'std_accuracy': 0.0019128828268973582}}
#
#
# Begin PassiveAggressiveClassifier
# Skipping training and validation accuracy calculation.
# PassiveAggressiveClassifier classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'PassiveAggressiveClassifier', 'metrics': {'accuracy': 1.0, 'weighted_precision': 1.0, 'wighted_recall': 1.0, 'weighted_f1': 1.0, 'macro_precision': 1.0, 'macro_recall': 1.0, 'macro_f1': 1.0, 'roc_auc': 1.0}, 'confusion_matrix': array([[496,   0],
#        [  0,  76]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9958011340673337, 'std_accuracy': 0.00284547459856951}}
#
#
# Begin ExtraTreesClassifier
# Skipping training and validation accuracy calculation.
# ExtraTreesClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'ExtraTreesClassifier', 'metrics': {'accuracy': 0.986013986013986, 'weighted_precision': 0.9862359862359862, 'wighted_recall': 0.986013986013986, 'weighted_f1': 0.9856814296814297, 'macro_precision': 0.9920634920634921, 'macro_recall': 0.9473684210526316, 'macro_f1': 0.9682222222222221, 'roc_auc': 0.9473684210526316}, 'confusion_matrix': array([[496,   0],
#        [  8,  68]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9783155548479542, 'std_accuracy': 0.004071301279403861}}
#
#
# Begin XGBClassifier
# Skipping training and validation accuracy calculation.
# XGBClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'XGBClassifier', 'metrics': {'accuracy': 0.9895104895104895, 'weighted_precision': 0.9899333390187048, 'wighted_recall': 0.9895104895104895, 'weighted_f1': 0.9896237365872993, 'macro_precision': 0.9677337398373984, 'macro_recall': 0.9883807300509337, 'macro_f1': 0.977732793522267, 'roc_auc': 0.9883807300509339}, 'confusion_matrix': array([[491,   5],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9856612739274736, 'std_accuracy': 0.004335101708253805}}
#
#
# Begin KNeighborsClassifier
# Skipping training and validation accuracy calculation.
# KNeighborsClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'KNeighborsClassifier', 'metrics': {'accuracy': 0.9912587412587412, 'weighted_precision': 0.9915136600375515, 'wighted_recall': 0.9912587412587412, 'weighted_f1': 0.9913300763622038, 'macro_precision': 0.9736693455208361, 'macro_recall': 0.9893887945670627, 'macro_f1': 0.9813431618774259, 'roc_auc': 0.9893887945670629}, 'confusion_matrix': array([[492,   4],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9863593499320296, 'std_accuracy': 0.004046023066533934}}
#
#
# Begin BaggingClassifier
# Skipping training and validation accuracy calculation.
# BaggingClassifier classification report
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'BaggingClassifier', 'metrics': {'accuracy': 0.9737762237762237, 'weighted_precision': 0.9733344133032957, 'wighted_recall': 0.9737762237762237, 'weighted_f1': 0.9732351111661458, 'macro_precision': 0.9600800991154522, 'macro_recall': 0.9235993208828523, 'macro_f1': 0.940768354561458, 'roc_auc': 0.9235993208828522}, 'confusion_matrix': array([[492,   4],
#        [ 11,  65]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9629242036422422, 'std_accuracy': 0.0013050839322208303}}
#
#
# Begin VotingClassifier
# Skipping training and validation accuracy calculation.
# VotingClassifier classification report
# Model does not support probability prediction. Skipping ROC curve plotting.
# {'dataset': 'ling_lemmatized_tfidf', 'model': 'VotingClassifier', 'metrics': {'accuracy': 0.9912587412587412, 'weighted_precision': 0.9913459793699314, 'wighted_recall': 0.9912587412587412, 'weighted_f1': 0.9911319992993584, 'macro_precision': 0.9950099800399201, 'macro_recall': 0.9671052631578947, 'macro_f1': 0.9804856747112085, 'roc_auc': 0.9671052631578947}, 'confusion_matrix': array([[496,   0],
#        [  5,  71]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9877585636780033, 'std_accuracy': 0.0044213195167173164}}

# %%
print(metric_results)

def convert(dic):
    dic["confusion_matrix"] = dic["confusion_matrix"].tolist()
    return dic

metric_results = list(map(convert, metric_results))

add_to_json_array("./ling_classification_report.json", metric_results, mode="overwrite")
# Out:
# [{'dataset': 'ling_lemmatized_tfidf', 'model': 'LinearSVC', 'metrics': {'accuracy': 0.9982517482517482, 'weighted_precision': 0.9982552658608996, 'wighted_recall': 0.9982517482517482, 'weighted_f1': 0.9982468396265639, 'macro_precision': 0.9989939637826961, 'macro_recall': 0.993421052631579, 'macro_f1': 0.9961852170491454, 'roc_auc': 0.993421052631579}, 'confusion_matrix': array([[496,   0],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9912556795218791, 'std_accuracy': 0.004944806457188462}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'MultinomialNB', 'metrics': {'accuracy': 0.9877622377622378, 'weighted_precision': 0.9879325445925843, 'wighted_recall': 0.9877622377622378, 'weighted_f1': 0.9875097185442012, 'macro_precision': 0.9930417495029822, 'macro_recall': 0.9539473684210527, 'macro_f1': 0.9723585654620137, 'roc_auc': 0.9539473684210527}, 'confusion_matrix': array([[496,   0],
#        [  7,  69]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9727162504745692, 'std_accuracy': 0.008823117011988965}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'BernoulliNB', 'metrics': {'accuracy': 0.9842657342657343, 'weighted_precision': 0.9845461469223845, 'wighted_recall': 0.9842657342657343, 'weighted_f1': 0.9838413334916832, 'macro_precision': 0.9910891089108911, 'macro_recall': 0.9407894736842105, 'macro_f1': 0.964035964035964, 'roc_auc': 0.9407894736842105}, 'confusion_matrix': array([[496,   0],
#        [  9,  67]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9671249066170257, 'std_accuracy': 0.011819431302090783}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'RandomForestClassifier', 'metrics': {'accuracy': 0.9842657342657343, 'weighted_precision': 0.9845461469223845, 'wighted_recall': 0.9842657342657343, 'weighted_f1': 0.9838413334916832, 'macro_precision': 0.9910891089108911, 'macro_recall': 0.9407894736842105, 'macro_f1': 0.964035964035964, 'roc_auc': 0.9407894736842105}, 'confusion_matrix': array([[496,   0],
#        [  9,  67]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9790166925893722, 'std_accuracy': 0.006720090897629651}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'DecisionTreeClassifier', 'metrics': {'accuracy': 0.9685314685314685, 'weighted_precision': 0.9678831129030333, 'wighted_recall': 0.9685314685314685, 'weighted_f1': 0.9679794496551298, 'macro_precision': 0.9451906659077973, 'macro_recall': 0.9150042444821731, 'macro_f1': 0.9293381283114175, 'roc_auc': 0.9150042444821732}, 'confusion_matrix': array([[490,   6],
#        [ 12,  64]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9548791838634221, 'std_accuracy': 0.004613521579600063}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'AdaBoostClassifier', 'metrics': {'accuracy': 0.9877622377622378, 'weighted_precision': 0.9877063781289133, 'wighted_recall': 0.9877622377622378, 'weighted_f1': 0.9877278773859475, 'macro_precision': 0.9759758551307847, 'macro_recall': 0.9706600169779287, 'macro_f1': 0.9732965193440174, 'roc_auc': 0.9706600169779286}, 'confusion_matrix': array([[493,   3],
#        [  4,  72]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9818120583444576, 'std_accuracy': 0.005593653514790113}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'LogisticRegression', 'metrics': {'accuracy': 0.9807692307692307, 'weighted_precision': 0.9811864663935669, 'wighted_recall': 0.9807692307692307, 'weighted_f1': 0.9801245472529493, 'macro_precision': 0.9891518737672584, 'macro_recall': 0.9276315789473684, 'macro_f1': 0.9555093584494743, 'roc_auc': 0.9276315789473684}, 'confusion_matrix': array([[496,   0],
#        [ 11,  65]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9646718430431214, 'std_accuracy': 0.00873915679653664}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'SGDClassifier', 'metrics': {'accuracy': 0.9965034965034965, 'weighted_precision': 0.9965175386862134, 'wighted_recall': 0.9965034965034965, 'weighted_f1': 0.9964837040893378, 'macro_precision': 0.9979919678714859, 'macro_recall': 0.986842105263158, 'macro_f1': 0.9923272971160295, 'roc_auc': 0.986842105263158}, 'confusion_matrix': array([[496,   0],
#        [  2,  74]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9940528823190821, 'std_accuracy': 0.003602254155093064}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'Perceptron', 'metrics': {'accuracy': 0.9912587412587412, 'weighted_precision': 0.9915136600375515, 'wighted_recall': 0.9912587412587412, 'weighted_f1': 0.9913300763622038, 'macro_precision': 0.9736693455208361, 'macro_recall': 0.9893887945670627, 'macro_f1': 0.9813431618774259, 'roc_auc': 0.9893887945670629}, 'confusion_matrix': array([[492,   4],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9912562918692516, 'std_accuracy': 0.0019128828268973582}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'PassiveAggressiveClassifier', 'metrics': {'accuracy': 1.0, 'weighted_precision': 1.0, 'wighted_recall': 1.0, 'weighted_f1': 1.0, 'macro_precision': 1.0, 'macro_recall': 1.0, 'macro_f1': 1.0, 'roc_auc': 1.0}, 'confusion_matrix': array([[496,   0],
#        [  0,  76]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9958011340673337, 'std_accuracy': 0.00284547459856951}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'ExtraTreesClassifier', 'metrics': {'accuracy': 0.986013986013986, 'weighted_precision': 0.9862359862359862, 'wighted_recall': 0.986013986013986, 'weighted_f1': 0.9856814296814297, 'macro_precision': 0.9920634920634921, 'macro_recall': 0.9473684210526316, 'macro_f1': 0.9682222222222221, 'roc_auc': 0.9473684210526316}, 'confusion_matrix': array([[496,   0],
#        [  8,  68]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9783155548479542, 'std_accuracy': 0.004071301279403861}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'XGBClassifier', 'metrics': {'accuracy': 0.9895104895104895, 'weighted_precision': 0.9899333390187048, 'wighted_recall': 0.9895104895104895, 'weighted_f1': 0.9896237365872993, 'macro_precision': 0.9677337398373984, 'macro_recall': 0.9883807300509337, 'macro_f1': 0.977732793522267, 'roc_auc': 0.9883807300509339}, 'confusion_matrix': array([[491,   5],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9856612739274736, 'std_accuracy': 0.004335101708253805}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'KNeighborsClassifier', 'metrics': {'accuracy': 0.9912587412587412, 'weighted_precision': 0.9915136600375515, 'wighted_recall': 0.9912587412587412, 'weighted_f1': 0.9913300763622038, 'macro_precision': 0.9736693455208361, 'macro_recall': 0.9893887945670627, 'macro_f1': 0.9813431618774259, 'roc_auc': 0.9893887945670629}, 'confusion_matrix': array([[492,   4],
#        [  1,  75]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9863593499320296, 'std_accuracy': 0.004046023066533934}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'BaggingClassifier', 'metrics': {'accuracy': 0.9737762237762237, 'weighted_precision': 0.9733344133032957, 'wighted_recall': 0.9737762237762237, 'weighted_f1': 0.9732351111661458, 'macro_precision': 0.9600800991154522, 'macro_recall': 0.9235993208828523, 'macro_f1': 0.940768354561458, 'roc_auc': 0.9235993208828522}, 'confusion_matrix': array([[492,   4],
#        [ 11,  65]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9629242036422422, 'std_accuracy': 0.0013050839322208303}}, {'dataset': 'ling_lemmatized_tfidf', 'model': 'VotingClassifier', 'metrics': {'accuracy': 0.9912587412587412, 'weighted_precision': 0.9913459793699314, 'wighted_recall': 0.9912587412587412, 'weighted_f1': 0.9911319992993584, 'macro_precision': 0.9950099800399201, 'macro_recall': 0.9671052631578947, 'macro_f1': 0.9804856747112085, 'roc_auc': 0.9671052631578947}, 'confusion_matrix': array([[496,   0],
#        [  5,  71]], dtype=int64), 'epochs': 10, 'k_fold_scores': {'mean_accuracy': 0.9877585636780033, 'std_accuracy': 0.0044213195167173164}}]
